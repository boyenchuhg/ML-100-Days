# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %%
# 把連結填入
library(readr)
data <- read_delim("https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt", col_names = F, delim="\t")
data
# Out:
# Parsed with column specification:
# cols(
#   X1 = col_character(),
#   X2 = col_character()
# )
#      X1
# 1    n00015388_157
# 2    n00015388_238
# 3    n00015388_304
# 4    n00015388_327
# 5    n00015388_355
# 6    n00015388_373
# 7    n00015388_379
# 8    n00015388_388
# 9    n00015388_442
# 10   n00015388_474
# 11   n00015388_514
# 12   n00015388_671
# 13   n00015388_686
# 14   n00015388_706
# 15   n00015388_725
# 16   n00015388_758
# 17   n00015388_841
# 18   n00015388_842
# 19   n00015388_1087
# 20   n00015388_1145
# 21   n00015388_1184
# 22   n00015388_1191
# 23   n00015388_1224
# 24   n00015388_1457
# 25   n00015388_1476
# 26   n00015388_1530
# 27   n00015388_1574
# 28   n00015388_1608
# 29   n00015388_1640
# 30   n00015388_1688
# ...  ...
# 9966 n00433802_5040
# 9967 n00433802_5045
# 9968 n00433802_5046
# 9969 n00433802_5048
# 9970 n00433802_5070
# 9971 n00433802_5076
# 9972 n00433802_5077
# 9973 n00433802_5103
# 9974 n00433802_5108
# 9975 n00433802_5114
# ...

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
as.data.frame(data)
# Out:
#      X1
# 1    n00015388_157
# 2    n00015388_238
# 3    n00015388_304
# 4    n00015388_327
# 5    n00015388_355
# 6    n00015388_373
# 7    n00015388_379
# 8    n00015388_388
# 9    n00015388_442
# 10   n00015388_474
# 11   n00015388_514
# 12   n00015388_671
# 13   n00015388_686
# 14   n00015388_706
# 15   n00015388_725
# 16   n00015388_758
# 17   n00015388_841
# 18   n00015388_842
# 19   n00015388_1087
# 20   n00015388_1145
# 21   n00015388_1184
# 22   n00015388_1191
# 23   n00015388_1224
# 24   n00015388_1457
# 25   n00015388_1476
# 26   n00015388_1530
# 27   n00015388_1574
# 28   n00015388_1608
# 29   n00015388_1640
# 30   n00015388_1688
# ...  ...
# 9966 n00433802_5040
# 9967 n00433802_5045
# 9968 n00433802_5046
# 9969 n00433802_5048
# 9970 n00433802_5070
# 9971 n00433802_5076
# 9972 n00433802_5077
# 9973 n00433802_5103
# 9974 n00433802_5108
# 9975 n00433802_5114
# 9976 n00433802_5123
# 9977 n00433802_5124
# 9978 n00433802_5130
# 9979 n00433802_5136
# 9980 n00433802_5147
# ...

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
library(magick)
img <- c(as.character(data[1,2]), as.character(data[2,2]), as.character(data[3,2]), as.character(data[4,2]), as.character(data[5,2])
        )
image_read(img[1])
image_read(img[2])
image_read(img[3])
image_read(img[4])
image_read(img[5])
# Out:
#   format width height colorspace matte filesize density
# 1   JPEG   500    436       sRGB FALSE   136981 300x300
#   format width height colorspace matte filesize density
# 1   JPEG   500    322       sRGB FALSE    95991   72x72
#   format width height colorspace matte filesize density
# 1   JPEG   375    500       sRGB FALSE   166320   72x72
#   format width height colorspace matte filesize density
# 1   JPEG   500    375       sRGB FALSE   111559   72x72
# Error in download_url(path): Failed to download http://img100.imageshack.us/img100/3253/forrest004fs9.jpg (HTTP 404)
# Traceback:
#
# 1. image_read(img[5])
# 2. vapply(path, replace_url, character(1))
# 3. FUN(X[[i]], ...)
# 4. paste0(download_url(path), suffix)
# 5. download_url(path)
# 6. stop(sprintf("Failed to download %s (HTTP %d)", url, req$status))
