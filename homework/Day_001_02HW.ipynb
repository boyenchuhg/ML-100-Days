# %%
setwd("C:/Users/Zheng/Documents/GitHub/ML-100-Days/data/houseprice")

# %%
house <- read.csv("train.csv", header = TRUE, sep = ",") #讀入檔案

# %%
Model <- lm(house$SalePrice ~ house$GrLivArea)

# %%
summary(Model)
# Out:
# Call:
# lm(formula = house$SalePrice ~ house$GrLivArea)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -462999  -29800   -1124   21957  339832
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     18569.026   4480.755   4.144 3.61e-05 ***
# house$GrLivArea   107.130      2.794  38.348  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 56070 on 1458 degrees of freedom
# Multiple R-squared:  0.5021,	Adjusted R-squared:  0.5018
# F-statistic:  1471 on 1 and 1458 DF,  p-value: < 2.2e-16

# %%
plot(Model)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
MSE <- sum(residuals(Model)^2)/Model$df.residual

# %%
MAE <- sum(abs(residuals(Model)))/Model$df.residual

# %%
MSE
# Out:
# [1] 3144150265

# %%
MAE
# Out:
# [1] 37690.36
